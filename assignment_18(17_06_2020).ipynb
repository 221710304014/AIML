# %% [markdown]
# CSE-221710304014-C.Tharun Kumar Reddy

# %%
import pandas as pd
import numpy as np
import sklearn

# %%
data = pd.read_csv("https://raw.githubusercontent.com/sumathi16/Datasets/master/Human_Resources_Employee_Attrition.csv",nrows=200)
data
# Out:
#      satisfaction_level  last_evaluation  ...  department  salary
# 0                  0.38             0.53  ...       sales     low
# 1                  0.80             0.86  ...       sales  medium
# 2                  0.11             0.88  ...       sales  medium
# 3                  0.72             0.87  ...       sales     low
# 4                  0.37             0.52  ...       sales     low
# ..                  ...              ...  ...         ...     ...
# 195                0.09             0.80  ...   technical     low
# 196                0.27             0.54  ...   technical     low
# 197                0.10             0.91  ...   technical     low
# 198                0.10             0.89  ...   technical     low
# 199                0.77             0.94  ...     support     low
#
# [200 rows x 10 columns]

# %% [markdown]
# Read the data in the proper format based on the data you have selected
#
# 1. What is the data separator?
# 2.  It reads the content of a csv file at given path, then loads the content to a Dataframe and returns that. It uses comma (,) as default delimiter or separator while parsing a file.
# 3. Is the data contains header?
# 4. Yes,Data contains header,they are:
# 5. satisfaction_level
# 6. last_evaluation
# 7. number_of_projects
# 8. average_monthly_hours
# 9. years_at_company
# 10. work_accident -left
# 11. promotion_last_5years
# 12. department
# 13. salary

# %%
data.shape #how many rows and columns are there
# Out:
# (200, 10)

# %%
len(data.select_dtypes(include=['int64','float64']).columns)# no of Numerical columns
# Out:
# 8

# %%
len(data.select_dtypes(include=['object']).columns) # no of Categorial columns
# Out:
# 2

# %%
# Creating the copy of original data
new_d = data.copy()
new_d
# Out:
#      satisfaction_level  last_evaluation  ...  department  salary
# 0                  0.38             0.53  ...       sales     low
# 1                  0.80             0.86  ...       sales  medium
# 2                  0.11             0.88  ...       sales  medium
# 3                  0.72             0.87  ...       sales     low
# 4                  0.37             0.52  ...       sales     low
# ..                  ...              ...  ...         ...     ...
# 195                0.09             0.80  ...   technical     low
# 196                0.27             0.54  ...   technical     low
# 197                0.10             0.91  ...   technical     low
# 198                0.10             0.89  ...   technical     low
# 199                0.77             0.94  ...     support     low
#
# [200 rows x 10 columns]

# %% [markdown]
# Observe the data and check for missing data and duplicates based on entire data. Remove the duplicates Replace the missing values with a function of your choice

# %%
new_d.isna().sum() #No missing values to replace
# Out:
# satisfaction_level       0
# last_evaluation          0
# number_of_projects       0
# average_monthly_hours    0
# years_at_company         0
# work_accident            0
# left                     0
# promotion_last_5years    0
# department               0
# salary                   0
# dtype: int64

# %%
new_d.drop_duplicates()# No Duplicate values to remove
# Out:
#      satisfaction_level  last_evaluation  ...  department  salary
# 0                  0.38             0.53  ...       sales     low
# 1                  0.80             0.86  ...       sales  medium
# 2                  0.11             0.88  ...       sales  medium
# 3                  0.72             0.87  ...       sales     low
# 4                  0.37             0.52  ...       sales     low
# ..                  ...              ...  ...         ...     ...
# 195                0.09             0.80  ...   technical     low
# 196                0.27             0.54  ...   technical     low
# 197                0.10             0.91  ...   technical     low
# 198                0.10             0.89  ...   technical     low
# 199                0.77             0.94  ...     support     low
#
# [200 rows x 10 columns]

# %% [markdown]
# Apply standard scaler for all the columns

# %%
merge_d=pd.get_dummies(data,columns=['department','salary'])
merge_d
# Out:
#      satisfaction_level  last_evaluation  ...  salary_low  salary_medium
# 0                  0.38             0.53  ...           1              0
# 1                  0.80             0.86  ...           0              1
# 2                  0.11             0.88  ...           0              1
# 3                  0.72             0.87  ...           1              0
# 4                  0.37             0.52  ...           1              0
# ..                  ...              ...  ...         ...            ...
# 195                0.09             0.80  ...           1              0
# 196                0.27             0.54  ...           1              0
# 197                0.10             0.91  ...           1              0
# 198                0.10             0.89  ...           1              0
# 199                0.77             0.94  ...           1              0
#
# [200 rows x 20 columns]

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler() # creating an object
merge_d=sc.fit_transform(merge_d)
merge_d

C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, int64, float64 were all converted to float64 by StandardScaler.
  return self.partial_fit(X, y)
C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:464: DataConversionWarning: Data with input dtype uint8, int64, float64 were all converted to float64 by StandardScaler.
  return self.fit(X, **fit_params).transform(X)

# %%
merge_d=pd.DataFrame(merge_d)
merge_d
# Out:
#      satisfaction_level  last_evaluation  ...  salary_low  salary_medium
# 0                  0.38             0.53  ...           1              0
# 1                  0.80             0.86  ...           0              1
# 2                  0.11             0.88  ...           0              1
# 3                  0.72             0.87  ...           1              0
# 4                  0.37             0.52  ...           1              0
# ..                  ...              ...  ...         ...            ...
# 195                0.09             0.80  ...           1              0
# 196                0.27             0.54  ...           1              0
# 197                0.10             0.91  ...           1              0
# 198                0.10             0.89  ...           1              0
# 199                0.77             0.94  ...           1              0
#
# [200 rows x 20 columns]

# %% [markdown]
# Apply onehotencoder to a categorical column

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer

ct=ColumnTransformer(transformers=[('Encoder',OneHotEncoder(),['department'])],remainder="passthrough")

new_d=ct.fit_transform(data)
new_d=pd.DataFrame(new_d)
new_d=new_d.iloc[:,0:9]
new_d.columns=['dep_sales','dep_technical','dep_support','dep_product_mng','dep_marketing','dep_IT','dep_hr',
              'dep_accounting','dep_management']
new_d=pd.concat([data,new_d],axis=1)
new_d=new_d.drop('department',axis=1)
new_d
# Out:
#      satisfaction_level  last_evaluation  ...  dep_accounting  dep_management
# 0                  0.38             0.53  ...               0               0
# 1                  0.80             0.86  ...               0               0
# 2                  0.11             0.88  ...               0               0
# 3                  0.72             0.87  ...               0               0
# 4                  0.37             0.52  ...               0               0
# ..                  ...              ...  ...             ...             ...
# 195                0.09             0.80  ...               0               1
# 196                0.27             0.54  ...               0               1
# 197                0.10             0.91  ...               0               1
# 198                0.10             0.89  ...               0               1
# 199                0.77             0.94  ...               1               0
#
# [200 rows x 18 columns]

# %% [markdown]
# Apply labelEncoder to a categorical column

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
new_d.salary=le.fit_transform(new_d.salary)
new_d
# Out:
#      satisfaction_level  last_evaluation  ...  dep_accounting  dep_management
# 0                  0.38             0.53  ...               0               0
# 1                  0.80             0.86  ...               0               0
# 2                  0.11             0.88  ...               0               0
# 3                  0.72             0.87  ...               0               0
# 4                  0.37             0.52  ...               0               0
# ..                  ...              ...  ...             ...             ...
# 195                0.09             0.80  ...               0               1
# 196                0.27             0.54  ...               0               1
# 197                0.10             0.91  ...               0               1
# 198                0.10             0.89  ...               0               1
# 199                0.77             0.94  ...               1               0
#
# [200 rows x 18 columns]

# %% [markdown]
# Apply pd.get_dummies for the entire data frame and check how many columns added.

# %%
newd1=data.copy()
newd1=pd.get_dummies(newd1,columns=['department'])
newd1=pd.get_dummies(newd1,columns=['salary'])
newd1
# Out:
#      satisfaction_level  last_evaluation  ...  salary_low  salary_medium
# 0                  0.38             0.53  ...           1              0
# 1                  0.80             0.86  ...           0              1
# 2                  0.11             0.88  ...           0              1
# 3                  0.72             0.87  ...           1              0
# 4                  0.37             0.52  ...           1              0
# ..                  ...              ...  ...         ...            ...
# 195                0.09             0.80  ...           1              0
# 196                0.27             0.54  ...           1              0
# 197                0.10             0.91  ...           1              0
# 198                0.10             0.89  ...           1              0
# 199                0.77             0.94  ...           1              0
#
# [200 rows x 20 columns]

# %%
print("no of column added  are:",len(newd1.columns)-len(data.columns)+len(data.select_dtypes(include=['object']).columns))
# Out:
# no of column added  are: 12

# %%
#Select one column from your data(which is your output). Store output in y
y=data['salary']
y
# Out:
# 0         low
# 1      medium
# 2      medium
# 3         low
# 4         low
#         ...
# 195       low
# 196       low
# 197       low
# 198       low
# 199       low
# Name: salary, Length: 200, dtype: object

# %%
 # Except the output column, all the remaining columns are your inputs. Store all inputs in X.
X=data.drop('salary',axis=1)
X
# Out:
#      satisfaction_level  last_evaluation  ...  promotion_last_5years  department
# 0                  0.38             0.53  ...                      0       sales
# 1                  0.80             0.86  ...                      0       sales
# 2                  0.11             0.88  ...                      0       sales
# 3                  0.72             0.87  ...                      0       sales
# 4                  0.37             0.52  ...                      0       sales
# ..                  ...              ...  ...                    ...         ...
# 195                0.09             0.80  ...                      0   technical
# 196                0.27             0.54  ...                      0   technical
# 197                0.10             0.91  ...                      0   technical
# 198                0.10             0.89  ...                      0   technical
# 199                0.77             0.94  ...                      0     support
#
# ...

# %% [markdown]
# Split the data with a specific random state and make 25% of the data for testing and 75% of the data for training

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=2)
X_train
# Out:
#      satisfaction_level  last_evaluation  ...  promotion_last_5years   department
# 159                0.45             0.45  ...                      0    marketing
# 100                0.38             0.52  ...                      0        sales
# 11                 0.11             0.81  ...                      0        sales
# 187                0.40             0.46  ...                      0           hr
# 24                 0.40             0.53  ...                      0        sales
# ..                  ...              ...  ...                    ...          ...
# 43                 0.10             0.80  ...                      0    technical
# 22                 0.09             0.95  ...                      0        sales
# 72                 0.45             0.49  ...                      0  product_mng
# 15                 0.38             0.54  ...                      0        sales
# ...

# %%
y_train
# Out:
# 159       low
# 100    medium
# 11        low
# 187    medium
# 24        low
#         ...
# 43        low
# 22        low
# 72       high
# 15        low
# 168       low
# Name: salary, Length: 150, dtype: object

# %%
X_test
# Out:
#      satisfaction_level  last_evaluation  ...  promotion_last_5years   department
# 112                0.43             0.52  ...                      0    technical
# 29                 0.38             0.50  ...                      0   accounting
# 182                0.89             0.99  ...                      0   accounting
# 199                0.77             0.94  ...                      0      support
# 193                0.09             0.82  ...                      0    technical
# 85                 0.11             0.87  ...                      0    marketing
# 10                 0.45             0.54  ...                      0        sales
# 54                 0.10             0.92  ...                      0      support
# 115                0.37             0.48  ...                      0    technical
# 35                 0.10             0.94  ...                      0    technical
# ...

# %%
y_test
# Out:
# 112       low
# 29        low
# 182    medium
# 199       low
# 193    medium
# 85        low
# 10        low
# 54        low
# 115    medium
# 35        low
# 12        low
# 92        low
# 13        low
# 126       low
# 174       low
# 2      medium
# 44        low
# 3         low
# 113    medium
# 14        low
# 23        low
# 25        low
# 6         low
# 134       low
# 165       low
# 173       low
# 45        low
# 65     medium
# 48        low
# 122       low
# 178    medium
# 64     medium
# 9         low
# 57        low
# 78        low
# 71     medium
# 128       low
# 176       low
# 131       low
# 53        low
# 137       low
# 163       low
# 111      high
# 123       low
# 109    medium
# 141       low
# 41        low
# 130       low
# 140       low
# 5         low
# Name: salary, dtype: object

# %%
print("X_train:",X_train.shape)
print("X_test:",X_test.shape)
print("y_train:",y_train.shape)
print("y_test:",y_test.shape)
# Out:
# X_train: (150, 9)
# X_test: (50, 9)
# y_train: (150,)
# y_test: (50,)
